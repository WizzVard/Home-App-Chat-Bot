# %%
from langchain_community.graphs import Neo4jGraph
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
NEO4J_URL = os.environ["NEO4J_URL"]
NEO4J_USERNAME = os.environ["NEO4J_USERNAME"]
NEO4J_PASSWORD = os.environ["NEO4J_PASSWORD"]
NEO4J_DATABASE = os.environ["NEO4J_DATABASE"]

# %%
graph = Neo4jGraph(url=NEO4J_URL, username=NEO4J_USERNAME, password=NEO4J_PASSWORD, database=NEO4J_DATABASE)

# %%
# Match all nodes in the graph
cypher = """
    MATCH (n)
    RETURN count(n) AS NumberOfNodes
"""
result = graph.query(cypher)
result
# Out:
# [{'NumberOfNodes': 9169}]

# %%
# Match only the Home nodes by specifying the node label
cypher = """
    MATCH (h:House)
    RETURN count(h) AS NumberOfHouses
"""
result = graph.query(cypher)
result
# Out:
# [{'NumberOfHouses': 4600}]

# %%
# Match only Country nodes
cypher = """
    MATCH (c:City)
    RETURN count(c) AS NumberOfCities
"""
result = graph.query(cypher)
result
# Out:
# [{'NumberOfCities': 44}]

# %%
# Match only Street nodes
cypher = """
    MATCH (s:Street)
    RETURN count(s) AS NumberOfStreets
"""
result = graph.query(cypher)
result
# Out:
# [{'NumberOfStreets': 4525}]

# %%
# Match houses by specifying the value of the 'bedroom' property on the 'House' node
cypher = """
    MATCH (h:House {bedrooms: 1})
    RETURN h
"""
result = graph.query(cypher)
result
# Out:
# [{'h': {'bedrooms': 1,
#    'condition': 2,
#    'sqft_basement': 280,
#    'sqft_living': 1100,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1947,
#    'price': 250000,
#    'sqft_lot': 4373,
#    'id': '260',
#    'yr_renovated': 0}},
#  {'h': {'bedrooms': 1,
#    'condition': 5,
#    'sqft_basement': 0,
#    'sqft_living': 810,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1941,
#    'price': 235000,
#    'sqft_lot': 2451,
#    'id': '477',
#    'yr_renovated': 0}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 0,
#    'sqft_living': 700,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1942,
#    'price': 350000,
#    'sqft_lot': 5100,
#    'id': '784',
#    'yr_renovated': 1999}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 0,
#    'sqft_living': 1140,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1920,
#    'price': 540000,
#    'sqft_lot': 6700,
#    'id': '831',
#    'yr_renovated': 1979}},
#  {'h': {'bedrooms': 1,
#    'condition': 4,
#    'sqft_basement': 0,
#    'sqft_living': 810,
#    'baths': 2,
#    'floors': 2.0,
#    'yr_built': 1982,
#    'price': 285000,
#    'sqft_lot': 3211,
#    'id': '883',
#    'yr_renovated': 2011}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 670,
#    'sqft_living': 2140,
#    'baths': 2,
#    'floors': 1.0,
#    'yr_built': 1976,
#    'price': 458000,
#    'sqft_lot': 10350,
#    'id': '969',
#    'yr_renovated': 0}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 60,
#    'sqft_living': 820,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 2007,
#    'price': 194000,
#    'sqft_lot': 1060,
#    'id': '1018',
#    'yr_renovated': 0}},
#  {'h': {'bedrooms': 1,
#    'condition': 5,
#    'sqft_basement': 0,
#    'sqft_living': 960,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1945,
#    'price': 420850,
#    'sqft_lot': 40946,
#    'id': '1051',
#    'yr_renovated': 0}},
#  {'h': {'bedrooms': 1,
#    'condition': 5,
#    'sqft_basement': 290,
#    'sqft_living': 1170,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1962,
#    'price': 275000,
#    'sqft_lot': 14149,
#    'id': '1140',
#    'yr_renovated': 0}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 0,
#    'sqft_living': 550,
#    'baths': 1,
#    'floors': 2.0,
#    'yr_built': 2008,
#    'price': 353000,
#    'sqft_lot': 1279,
#    'id': '1216',
#    'yr_renovated': 0}},
#  {'h': {'bedrooms': 1,
#    'condition': 2,
#    'sqft_basement': 0,
#    'sqft_living': 430,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1912,
#    'price': 80000,
#    'sqft_lot': 5050,
#    'id': '1219',
#    'yr_renovated': 0}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 0,
#    'sqft_living': 820,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1999,
#    'price': 527550,
#    'sqft_lot': 59677,
#    'id': '1238',
#    'yr_renovated': 0}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 0,
#    'sqft_living': 750,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1918,
#    'price': 250000,
#    'sqft_lot': 4000,
#    'id': '1663',
#    'yr_renovated': 0}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 0,
#    'sqft_living': 730,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1911,
#    'price': 395000,
#    'sqft_lot': 3000,
#    'id': '1678',
#    'yr_renovated': 1979}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 0,
#    'sqft_living': 560,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1967,
#    'price': 299000,
#    'sqft_lot': 12120,
#    'id': '1833',
#    'yr_renovated': 2011}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 0,
#    'sqft_living': 790,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1942,
#    'price': 135000,
#    'sqft_lot': 13062,
#    'id': '1853',
#    'yr_renovated': 1999}},
#  {'h': {'bedrooms': 1,
#    'condition': 4,
#    'sqft_basement': 0,
#    'sqft_living': 650,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1967,
#    'price': 129000,
#    'sqft_lot': 15364,
#    'id': '1906',
#    'yr_renovated': 0}},
#  {'h': {'bedrooms': 1,
#    'condition': 4,
#    'sqft_basement': 200,
#    'sqft_living': 750,
#    'baths': 2,
#    'floors': 1.0,
#    'yr_built': 1946,
#    'price': 355000,
#    'sqft_lot': 20339,
#    'id': '2303',
#    'yr_renovated': 1989}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 0,
#    'sqft_living': 620,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1939,
#    'price': 148000,
#    'sqft_lot': 8261,
#    'id': '2318',
#    'yr_renovated': 1969}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 0,
#    'sqft_living': 420,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1922,
#    'price': 280000,
#    'sqft_lot': 6720,
#    'id': '2416',
#    'yr_renovated': 2008}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 200,
#    'sqft_living': 960,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1908,
#    'price': 332000,
#    'sqft_lot': 2640,
#    'id': '2560',
#    'yr_renovated': 1988}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 0,
#    'sqft_living': 930,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1948,
#    'price': 210000,
#    'sqft_lot': 7129,
#    'id': '2625',
#    'yr_renovated': 1994}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 0,
#    'sqft_living': 720,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1914,
#    'price': 190000,
#    'sqft_lot': 4800,
#    'id': '2765',
#    'yr_renovated': 1996}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 0,
#    'sqft_living': 380,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1963,
#    'price': 245000,
#    'sqft_lot': 15000,
#    'id': '2919',
#    'yr_renovated': 2008}},
#  {'h': {'bedrooms': 1,
#    'condition': 2,
#    'sqft_basement': 120,
#    'sqft_living': 800,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1931,
#    'price': 250000,
#    'sqft_lot': 16306,
#    'id': '2966',
#    'yr_renovated': 0}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 0,
#    'sqft_living': 720,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1907,
#    'price': 335000,
#    'sqft_lot': 5100,
#    'id': '3129',
#    'yr_renovated': 1983}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 0,
#    'sqft_living': 930,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1941,
#    'price': 190000,
#    'sqft_lot': 29258,
#    'id': '3326',
#    'yr_renovated': 1994}},
#  {'h': {'bedrooms': 1,
#    'condition': 4,
#    'sqft_basement': 0,
#    'sqft_living': 700,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1907,
#    'price': 295000,
#    'sqft_lot': 2500,
#    'id': '3590',
#    'yr_renovated': 0}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 100,
#    'sqft_living': 1170,
#    'baths': 2,
#    'floors': 2.0,
#    'yr_built': 2007,
#    'price': 235000,
#    'sqft_lot': 1456,
#    'id': '3605',
#    'yr_renovated': 0}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 0,
#    'sqft_living': 1100,
#    'baths': 1,
#    'floors': 3.0,
#    'yr_built': 2014,
#    'price': 516500,
#    'sqft_lot': 638,
#    'id': '3608',
#    'yr_renovated': 0}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 0,
#    'sqft_living': 1010,
#    'baths': 2,
#    'floors': 1.0,
#    'yr_built': 1911,
#    'price': 410000,
#    'sqft_lot': 5750,
#    'id': '3633',
#    'yr_renovated': 1948}},
#  {'h': {'bedrooms': 1,
#    'condition': 5,
#    'sqft_basement': 0,
#    'sqft_living': 370,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1923,
#    'price': 276000,
#    'sqft_lot': 1801,
#    'id': '3778',
#    'yr_renovated': 0}},
#  {'h': {'bedrooms': 1,
#    'condition': 4,
#    'sqft_basement': 0,
#    'sqft_living': 1150,
#    'baths': 2,
#    'floors': 1.0,
#    'yr_built': 1962,
#    'price': 115000,
#    'sqft_lot': 9812,
#    'id': '4113',
#    'yr_renovated': 0}},
#  {'h': {'bedrooms': 1,
#    'condition': 2,
#    'sqft_basement': 0,
#    'sqft_living': 850,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1906,
#    'price': 165000,
#    'sqft_lot': 8050,
#    'id': '4117',
#    'yr_renovated': 0}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 0,
#    'sqft_living': 730,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 2008,
#    'price': 321500,
#    'sqft_lot': 1942,
#    'id': '4237',
#    'yr_renovated': 0}},
#  {'h': {'bedrooms': 1,
#    'condition': 4,
#    'sqft_basement': 0,
#    'sqft_living': 590,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1926,
#    'price': 202000,
#    'sqft_lot': 833,
#    'id': '4338',
#    'yr_renovated': 1993}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 0,
#    'sqft_living': 720,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1940,
#    'price': 0,
#    'sqft_lot': 6000,
#    'id': '4442',
#    'yr_renovated': 1996}},
#  {'h': {'bedrooms': 1,
#    'condition': 3,
#    'sqft_basement': 0,
#    'sqft_living': 690,
#    'baths': 1,
#    'floors': 1.0,
#    'yr_built': 1928,
#    'price': 167500,
#    'sqft_lot': 1950,
#    'id': '4556',
#    'yr_renovated': 1954}}]

# %%
cypher = """
    MATCH (h:House)
    WHERE NOT (h)-[:LOCATED_IN]->(:City)
    RETURN h
"""
result = graph.query(cypher)
result
# Out:
# []

# %%
cypher = """
    MATCH (h:House)
    OPTIONAL MATCH (h)-[:LOCATED_IN]->(c:City)
    RETURN h.id, c.name
"""
result = graph.query(cypher)
result
# Out:
# [{'h.id': '0', 'c.name': 'Shoreline'},
#  {'h.id': '1', 'c.name': 'Seattle'},
#  {'h.id': '2', 'c.name': 'Kent'},
#  {'h.id': '3', 'c.name': 'Bellevue'},
#  {'h.id': '4', 'c.name': 'Redmond'},
#  {'h.id': '5', 'c.name': 'Seattle'},
#  {'h.id': '6', 'c.name': 'Redmond'},
#  {'h.id': '7', 'c.name': 'Maple Valley'},
#  {'h.id': '8', 'c.name': 'North Bend'},
#  {'h.id': '9', 'c.name': 'Seattle'},
#  {'h.id': '10', 'c.name': 'Lake Forest Park'},
#  {'h.id': '11', 'c.name': 'Seattle'},
#  {'h.id': '12', 'c.name': 'Sammamish'},
#  {'h.id': '13', 'c.name': 'Seattle'},
#  {'h.id': '14', 'c.name': 'Seattle'},
#  {'h.id': '15', 'c.name': 'Kent'},
#  {'h.id': '16', 'c.name': 'Bellevue'},
#  {'h.id': '17', 'c.name': 'Auburn'},
#  {'h.id': '18', 'c.name': 'Des Moines'},
#  {'h.id': '19', 'c.name': 'North Bend'},
#  {'h.id': '20', 'c.name': 'Seattle'},
#  {'h.id': '21', 'c.name': 'Bellevue'},
#  {'h.id': '22', 'c.name': 'Seattle'},
#  {'h.id': '23', 'c.name': 'Bothell'},
#  {'h.id': '24', 'c.name': 'Seattle'},
#  {'h.id': '25', 'c.name': 'Federal Way'},
#  {'h.id': '26', 'c.name': 'Seattle'},
#  {'h.id': '27', 'c.name': 'Kirkland'},
#  {'h.id': '28', 'c.name': 'Issaquah'},
#  {'h.id': '29', 'c.name': 'Seattle'},
#  {'h.id': '30', 'c.name': 'Kirkland'},
#  {'h.id': '31', 'c.name': 'Woodinville'},
#  {'h.id': '32', 'c.name': 'Seattle'},
#  {'h.id': '33', 'c.name': 'Shoreline'},
#  {'h.id': '34', 'c.name': 'Auburn'},
#  {'h.id': '35', 'c.name': 'Federal Way'},
#  {'h.id': '36', 'c.name': 'Seattle'},
#  {'h.id': '37', 'c.name': 'Maple Valley'},
#  {'h.id': '38', 'c.name': 'Normandy Park'},
#  {'h.id': '39', 'c.name': 'Seattle'},
#  {'h.id': '40', 'c.name': 'Fall City'},
#  {'h.id': '41', 'c.name': 'Renton'},
#  {'h.id': '42', 'c.name': 'Shoreline'},
#  {'h.id': '43', 'c.name': 'Seattle'},
#  {'h.id': '44', 'c.name': 'Seattle'},
#  {'h.id': '45', 'c.name': 'Woodinville'},
#  {'h.id': '46', 'c.name': 'Issaquah'},
#  {'h.id': '47', 'c.name': 'Renton'},
#  {'h.id': '48', 'c.name': 'Seattle'},
#  {'h.id': '49', 'c.name': 'Redmond'},
#  {'h.id': '50', 'c.name': 'Issaquah'},
#  {'h.id': '51', 'c.name': 'Sammamish'},
#  {'h.id': '52', 'c.name': 'Seattle'},
#  {'h.id': '53', 'c.name': 'Carnation'},
#  {'h.id': '54', 'c.name': 'Bothell'},
#  {'h.id': '55', 'c.name': 'Bellevue'},
#  {'h.id': '56', 'c.name': 'Auburn'},
#  {'h.id': '57', 'c.name': 'Snoqualmie'},
#  {'h.id': '58', 'c.name': 'Seattle'},
#  {'h.id': '59', 'c.name': 'Seattle'},
#  {'h.id': '60', 'c.name': 'Snoqualmie'},
#  {'h.id': '61', 'c.name': 'North Bend'},
#  {'h.id': '62', 'c.name': 'Renton'},
#  {'h.id': '63', 'c.name': 'Kent'},
#  {'h.id': '64', 'c.name': 'Renton'},
#  {'h.id': '65', 'c.name': 'Seattle'},
#  {'h.id': '66', 'c.name': 'Issaquah'},
#  {'h.id': '67', 'c.name': 'Snoqualmie'},
#  {'h.id': '68', 'c.name': 'Redmond'},
#  {'h.id': '69', 'c.name': 'Renton'},
#  {'h.id': '70', 'c.name': 'Auburn'},
#  {'h.id': '71', 'c.name': 'Seattle'},
#  {'h.id': '72', 'c.name': 'Seattle'},
#  {'h.id': '73', 'c.name': 'Sammamish'},
#  {'h.id': '74', 'c.name': 'Kirkland'},
#  {'h.id': '75', 'c.name': 'Seattle'},
#  {'h.id': '76', 'c.name': 'Seattle'},
#  {'h.id': '77', 'c.name': 'Sammamish'},
#  {'h.id': '78', 'c.name': 'Bellevue'},
#  {'h.id': '79', 'c.name': 'Issaquah'},
#  {'h.id': '80', 'c.name': 'Issaquah'},
#  {'h.id': '81', 'c.name': 'Sammamish'},
#  {'h.id': '82', 'c.name': 'Seattle'},
#  {'h.id': '83', 'c.name': 'Issaquah'},
#  {'h.id': '84', 'c.name': 'Kirkland'},
#  {'h.id': '85', 'c.name': 'Shoreline'},
#  {'h.id': '86', 'c.name': 'Seattle'},
#  {'h.id': '87', 'c.name': 'Kirkland'},
#  {'h.id': '88', 'c.name': 'Seattle'},
#  {'h.id': '89', 'c.name': 'Des Moines'},
#  {'h.id': '90', 'c.name': 'Kirkland'},
#  {'h.id': '91', 'c.name': 'Seattle'},
#  {'h.id': '92', 'c.name': 'Seattle'},
#  {'h.id': '93', 'c.name': 'Seattle'},
#  {'h.id': '94', 'c.name': 'Seattle'},
#  {'h.id': '95', 'c.name': 'Bellevue'},
#  {'h.id': '96', 'c.name': 'Seattle'},
#  {'h.id': '97', 'c.name': 'Federal Way'},
#  {'h.id': '98', 'c.name': 'Seattle'},
#  {'h.id': '99', 'c.name': 'Seattle'},
#  {'h.id': '100', 'c.name': 'Renton'},
#  {'h.id': '101', 'c.name': 'Redmond'},
#  {'h.id': '102', 'c.name': 'Bellevue'},
#  {'h.id': '103', 'c.name': 'Auburn'},
#  {'h.id': '104', 'c.name': 'Seattle'},
#  {'h.id': '105', 'c.name': 'Snoqualmie'},
#  {'h.id': '106', 'c.name': 'Bellevue'},
#  {'h.id': '107', 'c.name': 'Redmond'},
#  {'h.id': '108', 'c.name': 'Seattle'},
#  {'h.id': '109', 'c.name': 'Federal Way'},
#  {'h.id': '110', 'c.name': 'Seattle'},
#  {'h.id': '111', 'c.name': 'Maple Valley'},
#  {'h.id': '112', 'c.name': 'Duvall'},
#  {'h.id': '113', 'c.name': 'Issaquah'},
#  {'h.id': '114', 'c.name': 'Seattle'},
#  {'h.id': '115', 'c.name': 'Kirkland'},
#  {'h.id': '116', 'c.name': 'Seattle'},
#  {'h.id': '117', 'c.name': 'Burien'},
#  {'h.id': '118', 'c.name': 'Bellevue'},
#  {'h.id': '119', 'c.name': 'Sammamish'},
#  {'h.id': '120', 'c.name': 'Shoreline'},
#  {'h.id': '121', 'c.name': 'Seattle'},
#  {'h.id': '122', 'c.name': 'Redmond'},
#  {'h.id': '123', 'c.name': 'Renton'},
#  {'h.id': '124', 'c.name': 'Seattle'},
#  {'h.id': '125', 'c.name': 'Seattle'},
#  {'h.id': '126', 'c.name': 'Seattle'},
#  {'h.id': '127', 'c.name': 'Seattle'},
#  {'h.id': '128', 'c.name': 'Auburn'},
#  {'h.id': '129', 'c.name': 'Renton'},
#  {'h.id': '130', 'c.name': 'Sammamish'},
#  {'h.id': '131', 'c.name': 'Renton'},
#  {'h.id': '132', 'c.name': 'Des Moines'},
#  {'h.id': '133', 'c.name': 'Seattle'},
#  {'h.id': '134', 'c.name': 'Seattle'},
#  {'h.id': '135', 'c.name': 'Redmond'},
#  {'h.id': '136', 'c.name': 'Seattle'},
#  {'h.id': '137', 'c.name': 'Kirkland'},
#  {'h.id': '138', 'c.name': 'Issaquah'},
#  {'h.id': '139', 'c.name': 'Seattle'},
#  {'h.id': '140', 'c.name': 'Issaquah'},
#  {'h.id': '141', 'c.name': 'Seattle'},
#  {'h.id': '142', 'c.name': 'Redmond'},
#  {'h.id': '143', 'c.name': 'Issaquah'},
#  {'h.id': '144', 'c.name': 'Seattle'},
#  {'h.id': '145', 'c.name': 'Issaquah'},
#  {'h.id': '146', 'c.name': 'Seattle'},
#  {'h.id': '147', 'c.name': 'Renton'},
#  {'h.id': '148', 'c.name': 'Issaquah'},
#  {'h.id': '149', 'c.name': 'Issaquah'},
#  {'h.id': '150', 'c.name': 'Redmond'},
#  {'h.id': '151', 'c.name': 'Kirkland'},
#  {'h.id': '152', 'c.name': 'Seattle'},
#  {'h.id': '153', 'c.name': 'Seattle'},
#  {'h.id': '154', 'c.name': 'Redmond'},
#  {'h.id': '155', 'c.name': 'Covington'},
#  {'h.id': '156', 'c.name': 'Seattle'},
#  {'h.id': '157', 'c.name': 'Seattle'},
#  {'h.id': '158', 'c.name': 'Seattle'},
#  {'h.id': '159', 'c.name': 'Seattle'},
#  {'h.id': '160', 'c.name': 'Des Moines'},
#  {'h.id': '161', 'c.name': 'Issaquah'},
#  {'h.id': '162', 'c.name': 'Seattle'},
#  {'h.id': '163', 'c.name': 'Seattle'},
#  {'h.id': '164', 'c.name': 'Seattle'},
#  {'h.id': '165', 'c.name': 'Seattle'},
#  {'h.id': '166', 'c.name': 'Inglewood-Finn Hill'},
#  {'h.id': '167', 'c.name': 'Seattle'},
#  {'h.id': '168', 'c.name': 'Shoreline'},
#  {'h.id': '169', 'c.name': 'Bellevue'},
#  {'h.id': '170', 'c.name': 'Kenmore'},
#  {'h.id': '171', 'c.name': 'Bellevue'},
#  {'h.id': '172', 'c.name': 'Des Moines'},
#  {'h.id': '173', 'c.name': 'Carnation'},
#  {'h.id': '174', 'c.name': 'Burien'},
#  {'h.id': '175', 'c.name': 'Kirkland'},
#  {'h.id': '176', 'c.name': 'Kent'},
#  {'h.id': '177', 'c.name': 'Shoreline'},
#  {'h.id': '178', 'c.name': 'Kenmore'},
#  {'h.id': '179', 'c.name': 'Renton'},
#  {'h.id': '180', 'c.name': 'Renton'},
#  {'h.id': '181', 'c.name': 'Seattle'},
#  {'h.id': '182', 'c.name': 'Renton'},
#  {'h.id': '183', 'c.name': 'Kirkland'},
#  {'h.id': '184', 'c.name': 'Bellevue'},
#  {'h.id': '185', 'c.name': 'Kenmore'},
#  {'h.id': '186', 'c.name': 'Seattle'},
#  {'h.id': '187', 'c.name': 'Federal Way'},
#  {'h.id': '188', 'c.name': 'Bellevue'},
#  {'h.id': '189', 'c.name': 'Redmond'},
#  {'h.id': '190', 'c.name': 'Federal Way'},
#  {'h.id': '191', 'c.name': 'Seattle'},
#  {'h.id': '192', 'c.name': 'Seattle'},
#  {'h.id': '193', 'c.name': 'Seattle'},
#  {'h.id': '194', 'c.name': 'North Bend'},
#  {'h.id': '195', 'c.name': 'Sammamish'},
#  {'h.id': '196', 'c.name': 'Kenmore'},
#  {'h.id': '197', 'c.name': 'Bellevue'},
#  {'h.id': '198', 'c.name': 'Sammamish'},
#  {'h.id': '199', 'c.name': 'Seattle'},
#  {'h.id': '200', 'c.name': 'Sammamish'},
#  {'h.id': '201', 'c.name': 'Seattle'},
#  {'h.id': '202', 'c.name': 'Redmond'},
#  {'h.id': '203', 'c.name': 'Bellevue'},
#  {'h.id': '204', 'c.name': 'Sammamish'},
#  {'h.id': '205', 'c.name': 'Seattle'},
#  {'h.id': '206', 'c.name': 'Newcastle'},
#  {'h.id': '207', 'c.name': 'Auburn'},
#  {'h.id': '208', 'c.name': 'Newcastle'},
#  {'h.id': '209', 'c.name': 'Woodinville'},
#  {'h.id': '210', 'c.name': 'Shoreline'},
#  {'h.id': '211', 'c.name': 'Seattle'},
#  {'h.id': '212', 'c.name': 'Seattle'},
#  {'h.id': '213', 'c.name': 'Seattle'},
#  {'h.id': '214', 'c.name': 'Bellevue'},
#  {'h.id': '215', 'c.name': 'Auburn'},
#  {'h.id': '216', 'c.name': 'Seattle'},
#  {'h.id': '217', 'c.name': 'Mercer Island'},
#  {'h.id': '218', 'c.name': 'Federal Way'},
#  {'h.id': '219', 'c.name': 'Seattle'},
#  {'h.id': '220', 'c.name': 'Seattle'},
#  {'h.id': '221', 'c.name': 'Federal Way'},
#  {'h.id': '222', 'c.name': 'Seattle'},
#  {'h.id': '223', 'c.name': 'Seattle'},
#  {'h.id': '224', 'c.name': 'Seattle'},
#  {'h.id': '225', 'c.name': 'Renton'},
#  {'h.id': '226', 'c.name': 'Seattle'},
#  {'h.id': '227', 'c.name': 'Bellevue'},
#  {'h.id': '228', 'c.name': 'Redmond'},
#  {'h.id': '229', 'c.name': 'Seattle'},
#  {'h.id': '230', 'c.name': 'Burien'},
#  {'h.id': '231', 'c.name': 'Seattle'},
#  {'h.id': '232', 'c.name': 'Shoreline'},
#  {'h.id': '233', 'c.name': 'Redmond'},
#  {'h.id': '234', 'c.name': 'Black Diamond'},
#  {'h.id': '235', 'c.name': 'Kirkland'},
#  {'h.id': '236', 'c.name': 'Maple Valley'},
#  {'h.id': '237', 'c.name': 'Burien'},
#  {'h.id': '238', 'c.name': 'Renton'},
#  {'h.id': '239', 'c.name': 'Seattle'},
#  {'h.id': '240', 'c.name': 'Ravensdale'},
#  {'h.id': '241', 'c.name': 'Seattle'},
#  {'h.id': '242', 'c.name': 'Kirkland'},
#  {'h.id': '243', 'c.name': 'Covington'},
#  {'h.id': '244', 'c.name': 'Kent'},
#  {'h.id': '245', 'c.name': 'Redmond'},
#  {'h.id': '246', 'c.name': 'Bellevue'},
#  {'h.id': '247', 'c.name': 'Seattle'},
#  {'h.id': '248', 'c.name': 'Carnation'},
#  {'h.id': '249', 'c.name': 'Bothell'},
#  {'h.id': '250', 'c.name': 'Burien'},
#  {'h.id': '251', 'c.name': 'Federal Way'},
#  {'h.id': '252', 'c.name': 'Seattle'},
#  {'h.id': '253', 'c.name': 'Seattle'},
#  {'h.id': '254', 'c.name': 'Carnation'},
#  {'h.id': '255', 'c.name': 'Kirkland'},
#  {'h.id': '256', 'c.name': 'Bellevue'},
#  {'h.id': '257', 'c.name': 'Seattle'},
#  {'h.id': '258', 'c.name': 'Renton'},
#  {'h.id': '259', 'c.name': 'Seattle'},
#  {'h.id': '260', 'c.name': 'Burien'},
#  {'h.id': '261', 'c.name': 'Kirkland'},
#  {'h.id': '262', 'c.name': 'Kent'},
#  {'h.id': '263', 'c.name': 'Issaquah'},
#  {'h.id': '264', 'c.name': 'Seattle'},
#  {'h.id': '265', 'c.name': 'Seattle'},
#  {'h.id': '266', 'c.name': 'Seattle'},
#  {'h.id': '267', 'c.name': 'Kirkland'},
#  {'h.id': '268', 'c.name': 'Redmond'},
#  {'h.id': '269', 'c.name': 'Seattle'},
#  {'h.id': '270', 'c.name': 'Shoreline'},
#  {'h.id': '271', 'c.name': 'Renton'},
#  {'h.id': '272', 'c.name': 'Woodinville'},
#  {'h.id': '273', 'c.name': 'Clyde Hill'},
#  {'h.id': '274', 'c.name': 'Seattle'},
#  {'h.id': '275', 'c.name': 'Seattle'},
#  {'h.id': '276', 'c.name': 'Seattle'},
#  {'h.id': '277', 'c.name': 'Federal Way'},
#  {'h.id': '278', 'c.name': 'Issaquah'},
#  {'h.id': '279', 'c.name': 'Renton'},
#  {'h.id': '280', 'c.name': 'Seattle'},
#  {'h.id': '281', 'c.name': 'Seattle'},
#  {'h.id': '282', 'c.name': 'Redmond'},
#  {'h.id': '283', 'c.name': 'Renton'},
#  {'h.id': '284', 'c.name': 'Seattle'},
#  {'h.id': '285', 'c.name': 'Seattle'},
#  {'h.id': '286', 'c.name': 'Issaquah'},
#  {'h.id': '287', 'c.name': 'Kent'},
#  {'h.id': '288', 'c.name': 'Renton'},
#  {'h.id': '289', 'c.name': 'Seattle'},
#  {'h.id': '290', 'c.name': 'Algona'},
#  {'h.id': '291', 'c.name': 'Lake Forest Park'},
#  {'h.id': '292', 'c.name': 'Woodinville'},
#  {'h.id': '293', 'c.name': 'Auburn'},
#  {'h.id': '294', 'c.name': 'Seattle'},
#  {'h.id': '295', 'c.name': 'Seattle'},
#  {'h.id': '296', 'c.name': 'Issaquah'},
#  {'h.id': '297', 'c.name': 'Seattle'},
#  {'h.id': '298', 'c.name': 'Kent'},
#  {'h.id': '299', 'c.name': 'Federal Way'},
#  {'h.id': '300', 'c.name': 'Covington'},
#  {'h.id': '301', 'c.name': 'Seattle'},
#  {'h.id': '302', 'c.name': 'Kenmore'},
#  {'h.id': '303', 'c.name': 'Seattle'},
#  {'h.id': '304', 'c.name': 'Shoreline'},
#  {'h.id': '305', 'c.name': 'Maple Valley'},
#  {'h.id': '306', 'c.name': 'Seattle'},
#  {'h.id': '307', 'c.name': 'Burien'},
#  {'h.id': '308', 'c.name': 'Seattle'},
#  {'h.id': '309', 'c.name': 'Kirkland'},
#  {'h.id': '310', 'c.name': 'Kirkland'},
#  {'h.id': '311', 'c.name': 'Seattle'},
#  {'h.id': '312', 'c.name': 'Auburn'},
#  {'h.id': '313', 'c.name': 'Seattle'},
#  {'h.id': '314', 'c.name': 'Seattle'},
#  {'h.id': '315', 'c.name': 'Seattle'},
#  {'h.id': '316', 'c.name': 'Seattle'},
#  {'h.id': '317', 'c.name': 'Duvall'},
#  {'h.id': '318', 'c.name': 'Mercer Island'},
#  {'h.id': '319', 'c.name': 'Federal Way'},
#  {'h.id': '320', 'c.name': 'Seattle'},
#  {'h.id': '321', 'c.name': 'Sammamish'},
#  {'h.id': '322', 'c.name': 'Mercer Island'},
#  {'h.id': '323', 'c.name': 'Seattle'},
#  {'h.id': '324', 'c.name': 'Algona'},
#  {'h.id': '325', 'c.name': 'Issaquah'},
#  {'h.id': '326', 'c.name': 'Skykomish'},
#  {'h.id': '327', 'c.name': 'Kirkland'},
#  {'h.id': '328', 'c.name': 'Seattle'},
#  {'h.id': '329', 'c.name': 'Seattle'},
#  {'h.id': '330', 'c.name': 'Redmond'},
#  {'h.id': '331', 'c.name': 'Kent'},
#  {'h.id': '332', 'c.name': 'Kent'},
#  {'h.id': '333', 'c.name': 'Issaquah'},
#  {'h.id': '334', 'c.name': 'Seattle'},
#  {'h.id': '335', 'c.name': 'Kent'},
#  {'h.id': '336', 'c.name': 'Kent'},
#  {'h.id': '337', 'c.name': 'Normandy Park'},
#  {'h.id': '338', 'c.name': 'Seattle'},
#  {'h.id': '339', 'c.name': 'Redmond'},
#  {'h.id': '340', 'c.name': 'Kent'},
#  {'h.id': '341', 'c.name': 'Seattle'},
#  {'h.id': '342', 'c.name': 'Seattle'},
#  {'h.id': '343', 'c.name': 'Bellevue'},
#  {'h.id': '344', 'c.name': 'Kent'},
#  {'h.id': '345', 'c.name': 'Auburn'},
#  {'h.id': '346', 'c.name': 'Federal Way'},
#  {'h.id': '347', 'c.name': 'Seattle'},
#  {'h.id': '348', 'c.name': 'Kent'},
#  {'h.id': '349', 'c.name': 'Seattle'},
#  {'h.id': '350', 'c.name': 'Seattle'},
#  {'h.id': '351', 'c.name': 'Sammamish'},
#  {'h.id': '352', 'c.name': 'Seattle'},
#  {'h.id': '353', 'c.name': 'Seattle'},
#  {'h.id': '354', 'c.name': 'Redmond'},
#  {'h.id': '355', 'c.name': 'Bellevue'},
#  {'h.id': '356', 'c.name': 'Seattle'},
#  {'h.id': '357', 'c.name': 'Seattle'},
#  {'h.id': '358', 'c.name': 'Woodinville'},
#  {'h.id': '359', 'c.name': 'Bellevue'},
#  {'h.id': '360', 'c.name': 'Renton'},
#  {'h.id': '361', 'c.name': 'Seattle'},
#  {'h.id': '362', 'c.name': 'Woodinville'},
#  {'h.id': '363', 'c.name': 'Seattle'},
#  {'h.id': '364', 'c.name': 'Tukwila'},
#  {'h.id': '365', 'c.name': 'Redmond'},
#  {'h.id': '366', 'c.name': 'Seattle'},
#  {'h.id': '367', 'c.name': 'Kirkland'},
#  {'h.id': '368', 'c.name': 'Seattle'},
#  {'h.id': '369', 'c.name': 'Federal Way'},
#  {'h.id': '370', 'c.name': 'Renton'},
#  {'h.id': '371', 'c.name': 'Des Moines'},
#  {'h.id': '372', 'c.name': 'Burien'},
#  {'h.id': '373', 'c.name': 'Mercer Island'},
#  {'h.id': '374', 'c.name': 'Seattle'},
#  {'h.id': '375', 'c.name': 'Snoqualmie'},
#  {'h.id': '376', 'c.name': 'Redmond'},
#  {'h.id': '377', 'c.name': 'Algona'},
#  {'h.id': '378', 'c.name': 'Seattle'},
#  {'h.id': '379', 'c.name': 'Renton'},
#  {'h.id': '380', 'c.name': 'Seattle'},
#  {'h.id': '381', 'c.name': 'Burien'},
#  {'h.id': '382', 'c.name': 'Seattle'},
#  {'h.id': '383', 'c.name': 'Seattle'},
#  {'h.id': '384', 'c.name': 'Seattle'},
#  {'h.id': '385', 'c.name': 'Kenmore'},
#  {'h.id': '386', 'c.name': 'Seattle'},
#  {'h.id': '387', 'c.name': 'Seattle'},
#  {'h.id': '388', 'c.name': 'Woodinville'},
#  {'h.id': '389', 'c.name': 'Renton'},
#  {'h.id': '390', 'c.name': 'Renton'},
#  {'h.id': '391', 'c.name': 'Issaquah'},
#  {'h.id': '392', 'c.name': 'Seattle'},
#  {'h.id': '393', 'c.name': 'Auburn'},
#  {'h.id': '394', 'c.name': 'Covington'},
#  {'h.id': '395', 'c.name': 'Vashon'},
#  {'h.id': '396', 'c.name': 'Woodinville'},
#  {'h.id': '397', 'c.name': 'Sammamish'},
#  {'h.id': '398', 'c.name': 'Federal Way'},
#  {'h.id': '399', 'c.name': 'Renton'},
#  {'h.id': '400', 'c.name': 'Issaquah'},
#  {'h.id': '401', 'c.name': 'Lake Forest Park'},
#  {'h.id': '402', 'c.name': 'Seattle'},
#  {'h.id': '403', 'c.name': 'Seattle'},
#  {'h.id': '404', 'c.name': 'Sammamish'},
#  {'h.id': '405', 'c.name': 'Seattle'},
#  {'h.id': '406', 'c.name': 'Fall City'},
#  {'h.id': '407', 'c.name': 'Issaquah'},
#  {'h.id': '408', 'c.name': 'Seattle'},
#  {'h.id': '409', 'c.name': 'Snoqualmie'},
#  {'h.id': '410', 'c.name': 'Kirkland'},
#  {'h.id': '411', 'c.name': 'Seattle'},
#  {'h.id': '412', 'c.name': 'Renton'},
#  {'h.id': '413', 'c.name': 'Seattle'},
#  {'h.id': '414', 'c.name': 'Bellevue'},
#  {'h.id': '415', 'c.name': 'Auburn'},
#  {'h.id': '416', 'c.name': 'Federal Way'},
#  {'h.id': '417', 'c.name': 'Kent'},
#  {'h.id': '418', 'c.name': 'Woodinville'},
#  {'h.id': '419', 'c.name': 'Seattle'},
#  {'h.id': '420', 'c.name': 'Algona'},
#  {'h.id': '421', 'c.name': 'Issaquah'},
#  {'h.id': '422', 'c.name': 'Kenmore'},
#  {'h.id': '423', 'c.name': 'Seattle'},
#  {'h.id': '424', 'c.name': 'Seattle'},
#  {'h.id': '425', 'c.name': 'Kent'},
#  {'h.id': '426', 'c.name': 'Woodinville'},
#  {'h.id': '427', 'c.name': 'Kent'},
#  {'h.id': '428', 'c.name': 'Redmond'},
#  {'h.id': '429', 'c.name': 'Bellevue'},
#  {'h.id': '430', 'c.name': 'Redmond'},
#  {'h.id': '431', 'c.name': 'Auburn'},
#  {'h.id': '432', 'c.name': 'Renton'},
#  {'h.id': '433', 'c.name': 'Seattle'},
#  {'h.id': '434', 'c.name': 'Sammamish'},
#  {'h.id': '435', 'c.name': 'Burien'},
#  {'h.id': '436', 'c.name': 'Renton'},
#  {'h.id': '437', 'c.name': 'Renton'},
#  {'h.id': '438', 'c.name': 'Seattle'},
#  {'h.id': '439', 'c.name': 'Black Diamond'},
#  {'h.id': '440', 'c.name': 'North Bend'},
#  {'h.id': '441', 'c.name': 'Bellevue'},
#  {'h.id': '442', 'c.name': 'Sammamish'},
#  {'h.id': '443', 'c.name': 'Bellevue'},
#  {'h.id': '444', 'c.name': 'Redmond'},
#  {'h.id': '445', 'c.name': 'Ravensdale'},
#  {'h.id': '446', 'c.name': 'Ravensdale'},
#  {'h.id': '447', 'c.name': 'Seattle'},
#  {'h.id': '448', 'c.name': 'Federal Way'},
#  {'h.id': '449', 'c.name': 'Duvall'},
#  {'h.id': '450', 'c.name': 'Maple Valley'},
#  {'h.id': '451', 'c.name': 'Renton'},
#  {'h.id': '452', 'c.name': 'Mercer Island'},
#  {'h.id': '453', 'c.name': 'Seattle'},
#  {'h.id': '454', 'c.name': 'Woodinville'},
#  {'h.id': '455', 'c.name': 'Seattle'},
#  {'h.id': '456', 'c.name': 'Renton'},
#  {'h.id': '457', 'c.name': 'Seattle'},
#  {'h.id': '458', 'c.name': 'Kenmore'},
#  {'h.id': '459', 'c.name': 'Seattle'},
#  {'h.id': '460', 'c.name': 'Seattle'},
#  {'h.id': '461', 'c.name': 'Carnation'},
#  {'h.id': '462', 'c.name': 'Issaquah'},
#  {'h.id': '463', 'c.name': 'Seattle'},
#  {'h.id': '464', 'c.name': 'Seattle'},
#  {'h.id': '465', 'c.name': 'Maple Valley'},
#  {'h.id': '466', 'c.name': 'Seattle'},
#  {'h.id': '467', 'c.name': 'Kent'},
#  {'h.id': '468', 'c.name': 'Seattle'},
#  {'h.id': '469', 'c.name': 'Seattle'},
#  {'h.id': '470', 'c.name': 'Seattle'},
#  {'h.id': '471', 'c.name': 'Redmond'},
#  {'h.id': '472', 'c.name': 'Seattle'},
#  {'h.id': '473', 'c.name': 'Issaquah'},
#  {'h.id': '474', 'c.name': 'Clyde Hill'},
#  {'h.id': '475', 'c.name': 'Seattle'},
#  {'h.id': '476', 'c.name': 'Shoreline'},
#  {'h.id': '477', 'c.name': 'Seattle'},
#  {'h.id': '478', 'c.name': 'Mercer Island'},
#  {'h.id': '479', 'c.name': 'Auburn'},
#  {'h.id': '480', 'c.name': 'Bellevue'},
#  {'h.id': '481', 'c.name': 'Seattle'},
#  {'h.id': '482', 'c.name': 'Bellevue'},
#  {'h.id': '483', 'c.name': 'Mercer Island'},
#  {'h.id': '484', 'c.name': 'Duvall'},
#  {'h.id': '485', 'c.name': 'Seattle'},
#  {'h.id': '486', 'c.name': 'Bellevue'},
#  {'h.id': '487', 'c.name': 'Seattle'},
#  {'h.id': '488', 'c.name': 'Seattle'},
#  {'h.id': '489', 'c.name': 'Seattle'},
#  {'h.id': '490', 'c.name': 'Maple Valley'},
#  {'h.id': '491', 'c.name': 'Seattle'},
#  {'h.id': '492', 'c.name': 'Seattle'},
#  {'h.id': '493', 'c.name': 'Renton'},
#  {'h.id': '494', 'c.name': 'Sammamish'},
#  {'h.id': '495', 'c.name': 'Woodinville'},
#  {'h.id': '496', 'c.name': 'Auburn'},
#  {'h.id': '497', 'c.name': 'Renton'},
#  {'h.id': '498', 'c.name': 'Seattle'},
#  {'h.id': '499', 'c.name': 'Kirkland'},
#  {'h.id': '500', 'c.name': 'Seattle'},
#  {'h.id': '501', 'c.name': 'Seattle'},
#  {'h.id': '502', 'c.name': 'Redmond'},
#  {'h.id': '503', 'c.name': 'Burien'},
#  {'h.id': '504', 'c.name': 'Kirkland'},
#  {'h.id': '505', 'c.name': 'Mercer Island'},
#  {'h.id': '506', 'c.name': 'Mercer Island'},
#  {'h.id': '507', 'c.name': 'Maple Valley'},
#  {'h.id': '508', 'c.name': 'Seattle'},
#  {'h.id': '509', 'c.name': 'Kent'},
#  {'h.id': '510', 'c.name': 'Redmond'},
#  {'h.id': '511', 'c.name': 'Seattle'},
#  {'h.id': '512', 'c.name': 'Shoreline'},
#  {'h.id': '513', 'c.name': 'Issaquah'},
#  {'h.id': '514', 'c.name': 'Issaquah'},
#  {'h.id': '515', 'c.name': 'Seattle'},
#  {'h.id': '516', 'c.name': 'Seattle'},
#  {'h.id': '517', 'c.name': 'Woodinville'},
#  {'h.id': '518', 'c.name': 'Burien'},
#  {'h.id': '519', 'c.name': 'Federal Way'},
#  {'h.id': '520', 'c.name': 'Seattle'},
#  {'h.id': '521', 'c.name': 'Redmond'},
#  {'h.id': '522', 'c.name': 'Normandy Park'},
#  {'h.id': '523', 'c.name': 'Seattle'},
#  {'h.id': '524', 'c.name': 'Seattle'},
#  {'h.id': '525', 'c.name': 'Clyde Hill'},
#  {'h.id': '526', 'c.name': 'Seattle'},
#  {'h.id': '527', 'c.name': 'Seattle'},
#  {'h.id': '528', 'c.name': 'Kirkland'},
#  {'h.id': '529', 'c.name': 'Maple Valley'},
#  {'h.id': '530', 'c.name': 'Bellevue'},
#  {'h.id': '531', 'c.name': 'Burien'},
#  {'h.id': '532', 'c.name': 'Seattle'},
#  {'h.id': '533', 'c.name': 'Seattle'},
#  {'h.id': '534', 'c.name': 'Mercer Island'},
#  {'h.id': '535', 'c.name': 'Vashon'},
#  {'h.id': '536', 'c.name': 'Seattle'},
#  {'h.id': '537', 'c.name': 'Bellevue'},
#  {'h.id': '538', 'c.name': 'Seattle'},
#  {'h.id': '539', 'c.name': 'Seattle'},
#  {'h.id': '540', 'c.name': 'Seattle'},
#  {'h.id': '541', 'c.name': 'Redmond'},
#  {'h.id': '542', 'c.name': 'Maple Valley'},
#  {'h.id': '543', 'c.name': 'Kirkland'},
#  {'h.id': '544', 'c.name': 'Renton'},
#  {'h.id': '545', 'c.name': 'Redmond'},
#  {'h.id': '546', 'c.name': 'Seattle'},
#  {'h.id': '547', 'c.name': 'Sammamish'},
#  {'h.id': '548', 'c.name': 'Woodinville'},
#  {'h.id': '549', 'c.name': 'Issaquah'},
#  {'h.id': '550', 'c.name': 'Kenmore'},
#  {'h.id': '551', 'c.name': 'Federal Way'},
#  {'h.id': '552', 'c.name': 'Redmond'},
#  {'h.id': '553', 'c.name': 'Shoreline'},
#  {'h.id': '554', 'c.name': 'Renton'},
#  {'h.id': '555', 'c.name': 'Kent'},
#  {'h.id': '556', 'c.name': 'Seattle'},
#  {'h.id': '557', 'c.name': 'Issaquah'},
#  {'h.id': '558', 'c.name': 'Bellevue'},
#  {'h.id': '559', 'c.name': 'Bellevue'},
#  {'h.id': '560', 'c.name': 'Seattle'},
#  {'h.id': '561', 'c.name': 'Redmond'},
#  {'h.id': '562', 'c.name': 'Seattle'},
#  {'h.id': '563', 'c.name': 'Seattle'},
#  {'h.id': '564', 'c.name': 'Yarrow Point'},
#  {'h.id': '565', 'c.name': 'Kent'},
#  {'h.id': '566', 'c.name': 'Duvall'},
#  {'h.id': '567', 'c.name': 'Seattle'},
#  {'h.id': '568', 'c.name': 'Auburn'},
#  {'h.id': '569', 'c.name': 'Seattle'},
#  {'h.id': '570', 'c.name': 'Bellevue'},
#  {'h.id': '571', 'c.name': 'Renton'},
#  {'h.id': '572', 'c.name': 'Seattle'},
#  {'h.id': '573', 'c.name': 'Seattle'},
#  {'h.id': '574', 'c.name': 'Seattle'},
#  {'h.id': '575', 'c.name': 'Seattle'},
#  {'h.id': '576', 'c.name': 'Bellevue'},
#  {'h.id': '577', 'c.name': 'Shoreline'},
#  {'h.id': '578', 'c.name': 'Sammamish'},
#  {'h.id': '579', 'c.name': 'Vashon'},
#  {'h.id': '580', 'c.name': 'Woodinville'},
#  {'h.id': '581', 'c.name': 'Seattle'},
#  {'h.id': '582', 'c.name': 'Seattle'},
#  {'h.id': '583', 'c.name': 'SeaTac'},
#  {'h.id': '584', 'c.name': 'Seattle'},
#  {'h.id': '585', 'c.name': 'Kirkland'},
#  {'h.id': '586', 'c.name': 'Seattle'},
#  {'h.id': '587', 'c.name': 'Seattle'},
#  {'h.id': '588', 'c.name': 'Kirkland'},
#  {'h.id': '589', 'c.name': 'Bellevue'},
#  {'h.id': '590', 'c.name': 'Newcastle'},
#  {'h.id': '591', 'c.name': 'Bellevue'},
#  {'h.id': '592', 'c.name': 'Mercer Island'},
#  {'h.id': '593', 'c.name': 'Shoreline'},
#  {'h.id': '594', 'c.name': 'Seattle'},
#  {'h.id': '595', 'c.name': 'Redmond'},
#  {'h.id': '596', 'c.name': 'Seattle'},
#  {'h.id': '597', 'c.name': 'Seattle'},
#  {'h.id': '598', 'c.name': 'Seattle'},
#  {'h.id': '599', 'c.name': 'Covington'},
#  {'h.id': '600', 'c.name': 'Bellevue'},
#  {'h.id': '601', 'c.name': 'Bellevue'},
#  {'h.id': '602', 'c.name': 'Bellevue'},
#  {'h.id': '603', 'c.name': 'Mercer Island'},
#  {'h.id': '604', 'c.name': 'Burien'},
#  {'h.id': '605', 'c.name': 'Normandy Park'},
#  {'h.id': '606', 'c.name': 'Mercer Island'},
#  {'h.id': '607', 'c.name': 'Seattle'},
#  {'h.id': '608', 'c.name': 'Lake Forest Park'},
#  {'h.id': '609', 'c.name': 'Seattle'},
#  {'h.id': '610', 'c.name': 'Auburn'},
#  {'h.id': '611', 'c.name': 'Mercer Island'},
#  {'h.id': '612', 'c.name': 'Auburn'},
#  {'h.id': '613', 'c.name': 'Woodinville'},
#  {'h.id': '614', 'c.name': 'Duvall'},
#  {'h.id': '615', 'c.name': 'Seattle'},
#  {'h.id': '616', 'c.name': 'Seattle'},
#  {'h.id': '617', 'c.name': 'Snoqualmie'},
#  {'h.id': '618', 'c.name': 'Kenmore'},
#  {'h.id': '619', 'c.name': 'Woodinville'},
#  {'h.id': '620', 'c.name': 'Seattle'},
#  {'h.id': '621', 'c.name': 'Snoqualmie'},
#  {'h.id': '622', 'c.name': 'Seattle'},
#  {'h.id': '623', 'c.name': 'Seattle'},
#  {'h.id': '624', 'c.name': 'Renton'},
#  {'h.id': '625', 'c.name': 'Seattle'},
#  {'h.id': '626', 'c.name': 'Seattle'},
#  {'h.id': '627', 'c.name': 'Seattle'},
#  {'h.id': '628', 'c.name': 'Seattle'},
#  {'h.id': '629', 'c.name': 'Mercer Island'},
#  {'h.id': '630', 'c.name': 'Bellevue'},
#  {'h.id': '631', 'c.name': 'Seattle'},
#  {'h.id': '632', 'c.name': 'Seattle'},
#  {'h.id': '633', 'c.name': 'Des Moines'},
#  {'h.id': '634', 'c.name': 'Federal Way'},
#  {'h.id': '635', 'c.name': 'Renton'},
#  {'h.id': '636', 'c.name': 'Sammamish'},
#  {'h.id': '637', 'c.name': 'Normandy Park'},
#  {'h.id': '638', 'c.name': 'Renton'},
#  {'h.id': '639', 'c.name': 'Kent'},
#  {'h.id': '640', 'c.name': 'Auburn'},
#  {'h.id': '641', 'c.name': 'Auburn'},
#  {'h.id': '642', 'c.name': 'Seattle'},
#  {'h.id': '643', 'c.name': 'Seattle'},
#  {'h.id': '644', 'c.name': 'Seattle'},
#  {'h.id': '645', 'c.name': 'Kirkland'},
#  {'h.id': '646', 'c.name': 'Seattle'},
#  {'h.id': '647', 'c.name': 'Issaquah'},
#  {'h.id': '648', 'c.name': 'Kenmore'},
#  {'h.id': '649', 'c.name': 'Seattle'},
#  {'h.id': '650', 'c.name': 'Seattle'},
#  {'h.id': '651', 'c.name': 'Maple Valley'},
#  {'h.id': '652', 'c.name': 'Seattle'},
#  {'h.id': '653', 'c.name': 'Newcastle'},
#  {'h.id': '654', 'c.name': 'Issaquah'},
#  {'h.id': '655', 'c.name': 'Woodinville'},
#  {'h.id': '656', 'c.name': 'Seattle'},
#  {'h.id': '657', 'c.name': 'Kent'},
#  {'h.id': '658', 'c.name': 'Shoreline'},
#  {'h.id': '659', 'c.name': 'Seattle'},
#  {'h.id': '660', 'c.name': 'Shoreline'},
#  {'h.id': '661', 'c.name': 'Seattle'},
#  {'h.id': '662', 'c.name': 'Auburn'},
#  {'h.id': '663', 'c.name': 'Seattle'},
#  {'h.id': '664', 'c.name': 'Fall City'},
#  {'h.id': '665', 'c.name': 'Kent'},
#  {'h.id': '666', 'c.name': 'Shoreline'},
#  {'h.id': '667', 'c.name': 'Auburn'},
#  {'h.id': '668', 'c.name': 'Bellevue'},
#  {'h.id': '669', 'c.name': 'Federal Way'},
#  {'h.id': '670', 'c.name': 'Kenmore'},
#  {'h.id': '671', 'c.name': 'Ravensdale'},
#  {'h.id': '672', 'c.name': 'Tukwila'},
#  {'h.id': '673', 'c.name': 'Duvall'},
#  {'h.id': '674', 'c.name': 'Seattle'},
#  {'h.id': '675', 'c.name': 'Woodinville'},
#  {'h.id': '676', 'c.name': 'Seattle'},
#  {'h.id': '677', 'c.name': 'Sammamish'},
#  {'h.id': '678', 'c.name': 'Renton'},
#  {'h.id': '679', 'c.name': 'Issaquah'},
#  {'h.id': '680', 'c.name': 'Renton'},
#  {'h.id': '681', 'c.name': 'Redmond'},
#  {'h.id': '682', 'c.name': 'Shoreline'},
#  {'h.id': '683', 'c.name': 'SeaTac'},
#  {'h.id': '684', 'c.name': 'Shoreline'},
#  {'h.id': '685', 'c.name': 'Auburn'},
#  {'h.id': '686', 'c.name': 'Kirkland'},
#  {'h.id': '687', 'c.name': 'Seattle'},
#  {'h.id': '688', 'c.name': 'Auburn'},
#  {'h.id': '689', 'c.name': 'Seattle'},
#  {'h.id': '690', 'c.name': 'Redmond'},
#  {'h.id': '691', 'c.name': 'Covington'},
#  {'h.id': '692', 'c.name': 'Bellevue'},
#  {'h.id': '693', 'c.name': 'Seattle'},
#  {'h.id': '694', 'c.name': 'Redmond'},
#  {'h.id': '695', 'c.name': 'Sammamish'},
#  {'h.id': '696', 'c.name': 'Bellevue'},
#  {'h.id': '697', 'c.name': 'Auburn'},
#  {'h.id': '698', 'c.name': 'Kirkland'},
#  {'h.id': '699', 'c.name': 'Federal Way'},
#  {'h.id': '700', 'c.name': 'Mercer Island'},
#  {'h.id': '701', 'c.name': 'Tukwila'},
#  {'h.id': '702', 'c.name': 'Renton'},
#  {'h.id': '703', 'c.name': 'Issaquah'},
#  {'h.id': '704', 'c.name': 'Sammamish'},
#  {'h.id': '705', 'c.name': 'Federal Way'},
#  {'h.id': '706', 'c.name': 'Sammamish'},
#  {'h.id': '707', 'c.name': 'Renton'},
#  {'h.id': '708', 'c.name': 'Auburn'},
#  {'h.id': '709', 'c.name': 'Bellevue'},
#  {'h.id': '710', 'c.name': 'Seattle'},
#  {'h.id': '711', 'c.name': 'Sammamish'},
#  {'h.id': '712', 'c.name': 'Kent'},
#  {'h.id': '713', 'c.name': 'Renton'},
#  {'h.id': '714', 'c.name': 'Seattle'},
#  {'h.id': '715', 'c.name': 'Renton'},
#  {'h.id': '716', 'c.name': 'Federal Way'},
#  {'h.id': '717', 'c.name': 'Seattle'},
#  {'h.id': '718', 'c.name': 'Federal Way'},
#  {'h.id': '719', 'c.name': 'Seattle'},
#  {'h.id': '720', 'c.name': 'Seattle'},
#  {'h.id': '721', 'c.name': 'Shoreline'},
#  {'h.id': '722', 'c.name': 'Kirkland'},
#  {'h.id': '723', 'c.name': 'Tukwila'},
#  {'h.id': '724', 'c.name': 'Seattle'},
#  {'h.id': '725', 'c.name': 'Redmond'},
#  {'h.id': '726', 'c.name': 'Bellevue'},
#  {'h.id': '727', 'c.name': 'Kenmore'},
#  {'h.id': '728', 'c.name': 'Redmond'},
#  {'h.id': '729', 'c.name': 'Kent'},
#  {'h.id': '730', 'c.name': 'Kenmore'},
#  {'h.id': '731', 'c.name': 'Renton'},
#  {'h.id': '732', 'c.name': 'Redmond'},
#  {'h.id': '733', 'c.name': 'North Bend'},
#  {'h.id': '734', 'c.name': 'Seattle'},
#  {'h.id': '735', 'c.name': 'Seattle'},
#  {'h.id': '736', 'c.name': 'Bellevue'},
#  {'h.id': '737', 'c.name': 'Seattle'},
#  {'h.id': '738', 'c.name': 'Issaquah'},
#  {'h.id': '739', 'c.name': 'Auburn'},
#  {'h.id': '740', 'c.name': 'Sammamish'},
#  {'h.id': '741', 'c.name': 'Issaquah'},
#  {'h.id': '742', 'c.name': 'Shoreline'},
#  {'h.id': '743', 'c.name': 'Seattle'},
#  {'h.id': '744', 'c.name': 'Maple Valley'},
#  {'h.id': '745', 'c.name': 'Medina'},
#  {'h.id': '746', 'c.name': 'Seattle'},
#  {'h.id': '747', 'c.name': 'Duvall'},
#  {'h.id': '748', 'c.name': 'Sammamish'},
#  {'h.id': '749', 'c.name': 'Federal Way'},
#  {'h.id': '750', 'c.name': 'Shoreline'},
#  {'h.id': '751', 'c.name': 'Woodinville'},
#  {'h.id': '752', 'c.name': 'Renton'},
#  {'h.id': '753', 'c.name': 'Woodinville'},
#  {'h.id': '754', 'c.name': 'Seattle'},
#  {'h.id': '755', 'c.name': 'Seattle'},
#  {'h.id': '756', 'c.name': 'Shoreline'},
#  {'h.id': '757', 'c.name': 'Seattle'},
#  {'h.id': '758', 'c.name': 'Seattle'},
#  {'h.id': '759', 'c.name': 'Seattle'},
#  {'h.id': '760', 'c.name': 'Bellevue'},
#  {'h.id': '761', 'c.name': 'Covington'},
#  {'h.id': '762', 'c.name': 'Seattle'},
#  {'h.id': '763', 'c.name': 'Kirkland'},
#  {'h.id': '764', 'c.name': 'Bellevue'},
#  {'h.id': '765', 'c.name': 'Seattle'},
#  {'h.id': '766', 'c.name': 'Seattle'},
#  {'h.id': '767', 'c.name': 'Seattle'},
#  {'h.id': '768', 'c.name': 'Lake Forest Park'},
#  {'h.id': '769', 'c.name': 'Seattle'},
#  {'h.id': '770', 'c.name': 'Renton'},
#  {'h.id': '771', 'c.name': 'Seattle'},
#  {'h.id': '772', 'c.name': 'Issaquah'},
#  {'h.id': '773', 'c.name': 'Seattle'},
#  {'h.id': '774', 'c.name': 'Redmond'},
#  {'h.id': '775', 'c.name': 'Seattle'},
#  {'h.id': '776', 'c.name': 'Issaquah'},
#  {'h.id': '777', 'c.name': 'Redmond'},
#  {'h.id': '778', 'c.name': 'Seattle'},
#  {'h.id': '779', 'c.name': 'Fall City'},
#  {'h.id': '780', 'c.name': 'Sammamish'},
#  {'h.id': '781', 'c.name': 'Newcastle'},
#  {'h.id': '782', 'c.name': 'Kent'},
#  {'h.id': '783', 'c.name': 'North Bend'},
#  {'h.id': '784', 'c.name': 'Seattle'},
#  {'h.id': '785', 'c.name': 'Snoqualmie'},
#  {'h.id': '786', 'c.name': 'Seattle'},
#  {'h.id': '787', 'c.name': 'Seattle'},
#  {'h.id': '788', 'c.name': 'Renton'},
#  {'h.id': '789', 'c.name': 'Seattle'},
#  {'h.id': '790', 'c.name': 'Seattle'},
#  {'h.id': '791', 'c.name': 'Seattle'},
#  {'h.id': '792', 'c.name': 'Federal Way'},
#  {'h.id': '793', 'c.name': 'Kirkland'},
#  {'h.id': '794', 'c.name': 'North Bend'},
#  {'h.id': '795', 'c.name': 'Tukwila'},
#  {'h.id': '796', 'c.name': 'Federal Way'},
#  {'h.id': '797', 'c.name': 'Issaquah'},
#  {'h.id': '798', 'c.name': 'Vashon'},
#  {'h.id': '799', 'c.name': 'Sammamish'},
#  {'h.id': '800', 'c.name': 'Kirkland'},
#  {'h.id': '801', 'c.name': 'Kent'},
#  {'h.id': '802', 'c.name': 'Seattle'},
#  {'h.id': '803', 'c.name': 'Renton'},
#  {'h.id': '804', 'c.name': 'Seattle'},
#  {'h.id': '805', 'c.name': 'Redmond'},
#  {'h.id': '806', 'c.name': 'Seattle'},
#  {'h.id': '807', 'c.name': 'Maple Valley'},
#  {'h.id': '808', 'c.name': 'Seattle'},
#  {'h.id': '809', 'c.name': 'Maple Valley'},
#  {'h.id': '810', 'c.name': 'Seattle'},
#  {'h.id': '811', 'c.name': 'Seattle'},
#  {'h.id': '812', 'c.name': 'Woodinville'},
#  {'h.id': '813', 'c.name': 'Kent'},
#  {'h.id': '814', 'c.name': 'Shoreline'},
#  {'h.id': '815', 'c.name': 'Des Moines'},
#  {'h.id': '816', 'c.name': 'Federal Way'},
#  {'h.id': '817', 'c.name': 'Woodinville'},
#  {'h.id': '818', 'c.name': 'Renton'},
#  {'h.id': '819', 'c.name': 'Kent'},
#  {'h.id': '820', 'c.name': 'Seattle'},
#  {'h.id': '821', 'c.name': 'Seattle'},
#  {'h.id': '822', 'c.name': 'Seattle'},
#  {'h.id': '823', 'c.name': 'Seattle'},
#  {'h.id': '824', 'c.name': 'Snoqualmie'},
#  {'h.id': '825', 'c.name': 'Seattle'},
#  {'h.id': '826', 'c.name': 'Seattle'},
#  {'h.id': '827', 'c.name': 'Kent'},
#  {'h.id': '828', 'c.name': 'Issaquah'},
#  {'h.id': '829', 'c.name': 'Bothell'},
#  {'h.id': '830', 'c.name': 'Des Moines'},
#  {'h.id': '831', 'c.name': 'Seattle'},
#  {'h.id': '832', 'c.name': 'Seattle'},
#  {'h.id': '833', 'c.name': 'Covington'},
#  {'h.id': '834', 'c.name': 'Sammamish'},
#  {'h.id': '835', 'c.name': 'Maple Valley'},
#  {'h.id': '836', 'c.name': 'Bellevue'},
#  {'h.id': '837', 'c.name': 'Seattle'},
#  {'h.id': '838', 'c.name': 'Kenmore'},
#  {'h.id': '839', 'c.name': 'Mercer Island'},
#  {'h.id': '840', 'c.name': 'Issaquah'},
#  {'h.id': '841', 'c.name': 'Snoqualmie'},
#  {'h.id': '842', 'c.name': 'Sammamish'},
#  {'h.id': '843', 'c.name': 'Seattle'},
#  {'h.id': '844', 'c.name': 'Snoqualmie'},
#  {'h.id': '845', 'c.name': 'Issaquah'},
#  {'h.id': '846', 'c.name': 'Shoreline'},
#  {'h.id': '847', 'c.name': 'Bellevue'},
#  {'h.id': '848', 'c.name': 'Seattle'},
#  {'h.id': '849', 'c.name': 'Seattle'},
#  {'h.id': '850', 'c.name': 'Renton'},
#  {'h.id': '851', 'c.name': 'Enumclaw'},
#  {'h.id': '852', 'c.name': 'Redmond'},
#  {'h.id': '853', 'c.name': 'Woodinville'},
#  {'h.id': '854', 'c.name': 'Snoqualmie'},
#  {'h.id': '855', 'c.name': 'Seattle'},
#  {'h.id': '856', 'c.name': 'Bellevue'},
#  {'h.id': '857', 'c.name': 'Renton'},
#  {'h.id': '858', 'c.name': 'Seattle'},
#  {'h.id': '859', 'c.name': 'Kent'},
#  {'h.id': '860', 'c.name': 'Seattle'},
#  {'h.id': '861', 'c.name': 'Federal Way'},
#  {'h.id': '862', 'c.name': 'Bellevue'},
#  {'h.id': '863', 'c.name': 'Renton'},
#  {'h.id': '864', 'c.name': 'Seattle'},
#  {'h.id': '865', 'c.name': 'Maple Valley'},
#  {'h.id': '866', 'c.name': 'Seattle'},
#  {'h.id': '867', 'c.name': 'Shoreline'},
#  {'h.id': '868', 'c.name': 'Seattle'},
#  {'h.id': '869', 'c.name': 'Seattle'},
#  {'h.id': '870', 'c.name': 'Seattle'},
#  {'h.id': '871', 'c.name': 'North Bend'},
#  {'h.id': '872', 'c.name': 'Seattle'},
#  {'h.id': '873', 'c.name': 'Seattle'},
#  {'h.id': '874', 'c.name': 'Vashon'},
#  {'h.id': '875', 'c.name': 'Seattle'},
#  {'h.id': '876', 'c.name': 'Kent'},
#  {'h.id': '877', 'c.name': 'Seattle'},
#  {'h.id': '878', 'c.name': 'Auburn'},
#  {'h.id': '879', 'c.name': 'North Bend'},
#  {'h.id': '880', 'c.name': 'Bellevue'},
#  {'h.id': '881', 'c.name': 'Auburn'},
#  {'h.id': '882', 'c.name': 'Seattle'},
#  {'h.id': '883', 'c.name': 'Kirkland'},
#  {'h.id': '884', 'c.name': 'Shoreline'},
#  {'h.id': '885', 'c.name': 'Issaquah'},
#  {'h.id': '886', 'c.name': 'Seattle'},
#  {'h.id': '887', 'c.name': 'Maple Valley'},
#  {'h.id': '888', 'c.name': 'Seattle'},
#  {'h.id': '889', 'c.name': 'Woodinville'},
#  {'h.id': '890', 'c.name': 'Seattle'},
#  {'h.id': '891', 'c.name': 'Federal Way'},
#  {'h.id': '892', 'c.name': 'Kent'},
#  {'h.id': '893', 'c.name': 'Renton'},
#  {'h.id': '894', 'c.name': 'Seattle'},
#  {'h.id': '895', 'c.name': 'Redmond'},
#  {'h.id': '896', 'c.name': 'Issaquah'},
#  {'h.id': '897', 'c.name': 'Woodinville'},
#  {'h.id': '898', 'c.name': 'Redmond'},
#  {'h.id': '899', 'c.name': 'Seattle'},
#  {'h.id': '900', 'c.name': 'Seattle'},
#  {'h.id': '901', 'c.name': 'Des Moines'},
#  {'h.id': '902', 'c.name': 'Issaquah'},
#  {'h.id': '903', 'c.name': 'Woodinville'},
#  {'h.id': '904', 'c.name': 'Redmond'},
#  {'h.id': '905', 'c.name': 'Renton'},
#  {'h.id': '906', 'c.name': 'Seattle'},
#  {'h.id': '907', 'c.name': 'Renton'},
#  {'h.id': '908', 'c.name': 'SeaTac'},
#  {'h.id': '909', 'c.name': 'Seattle'},
#  {'h.id': '910', 'c.name': 'Bellevue'},
#  {'h.id': '911', 'c.name': 'Renton'},
#  {'h.id': '912', 'c.name': 'Seattle'},
#  {'h.id': '913', 'c.name': 'Seattle'},
#  {'h.id': '914', 'c.name': 'Seattle'},
#  {'h.id': '915', 'c.name': 'Redmond'},
#  {'h.id': '916', 'c.name': 'Shoreline'},
#  {'h.id': '917', 'c.name': 'Carnation'},
#  {'h.id': '918', 'c.name': 'Renton'},
#  {'h.id': '919', 'c.name': 'Des Moines'},
#  {'h.id': '920', 'c.name': 'Seattle'},
#  {'h.id': '921', 'c.name': 'North Bend'},
#  {'h.id': '922', 'c.name': 'Kenmore'},
#  {'h.id': '923', 'c.name': 'Newcastle'},
#  {'h.id': '924', 'c.name': 'Seattle'},
#  {'h.id': '925', 'c.name': 'Seattle'},
#  {'h.id': '926', 'c.name': 'Bellevue'},
#  {'h.id': '927', 'c.name': 'Seattle'},
#  {'h.id': '928', 'c.name': 'Seattle'},
#  {'h.id': '929', 'c.name': 'Kirkland'},
#  {'h.id': '930', 'c.name': 'Redmond'},
#  {'h.id': '931', 'c.name': 'Seattle'},
#  {'h.id': '932', 'c.name': 'Federal Way'},
#  {'h.id': '933', 'c.name': 'Snoqualmie'},
#  {'h.id': '934', 'c.name': 'Sammamish'},
#  {'h.id': '935', 'c.name': 'Kenmore'},
#  {'h.id': '936', 'c.name': 'Seattle'},
#  {'h.id': '937', 'c.name': 'Normandy Park'},
#  {'h.id': '938', 'c.name': 'Seattle'},
#  {'h.id': '939', 'c.name': 'Seattle'},
#  {'h.id': '940', 'c.name': 'Seattle'},
#  {'h.id': '941', 'c.name': 'Seattle'},
#  {'h.id': '942', 'c.name': 'Renton'},
#  {'h.id': '943', 'c.name': 'Seattle'},
#  {'h.id': '944', 'c.name': 'Seattle'},
#  {'h.id': '945', 'c.name': 'Kent'},
#  {'h.id': '946', 'c.name': 'Seattle'},
#  {'h.id': '947', 'c.name': 'Seattle'},
#  {'h.id': '948', 'c.name': 'Redmond'},
#  {'h.id': '949', 'c.name': 'Seattle'},
#  {'h.id': '950', 'c.name': 'Redmond'},
#  {'h.id': '951', 'c.name': 'Renton'},
#  {'h.id': '952', 'c.name': 'Bellevue'},
#  {'h.id': '953', 'c.name': 'Seattle'},
#  {'h.id': '954', 'c.name': 'Seattle'},
#  {'h.id': '955', 'c.name': 'Seattle'},
#  {'h.id': '956', 'c.name': 'Seattle'},
#  {'h.id': '957', 'c.name': 'Bellevue'},
#  {'h.id': '958', 'c.name': 'Seattle'},
#  {'h.id': '959', 'c.name': 'Kirkland'},
#  {'h.id': '960', 'c.name': 'Auburn'},
#  {'h.id': '961', 'c.name': 'Kent'},
#  {'h.id': '962', 'c.name': 'Redmond'},
#  {'h.id': '963', 'c.name': 'Seattle'},
#  {'h.id': '964', 'c.name': 'Woodinville'},
#  {'h.id': '965', 'c.name': 'Redmond'},
#  {'h.id': '966', 'c.name': 'Redmond'},
#  {'h.id': '967', 'c.name': 'Renton'},
#  {'h.id': '968', 'c.name': 'Seattle'},
#  {'h.id': '969', 'c.name': 'Woodinville'},
#  {'h.id': '970', 'c.name': 'Bellevue'},
#  {'h.id': '971', 'c.name': 'Maple Valley'},
#  {'h.id': '972', 'c.name': 'Renton'},
#  {'h.id': '973', 'c.name': 'Kenmore'},
#  {'h.id': '974', 'c.name': 'Seattle'},
#  {'h.id': '975', 'c.name': 'Seattle'},
#  {'h.id': '976', 'c.name': 'Maple Valley'},
#  {'h.id': '977', 'c.name': 'Seattle'},
#  {'h.id': '978', 'c.name': 'Auburn'},
#  {'h.id': '979', 'c.name': 'Seattle'},
#  {'h.id': '980', 'c.name': 'Renton'},
#  {'h.id': '981', 'c.name': 'Shoreline'},
#  {'h.id': '982', 'c.name': 'Seattle'},
#  {'h.id': '983', 'c.name': 'Renton'},
#  {'h.id': '984', 'c.name': 'Seattle'},
#  {'h.id': '985', 'c.name': 'Seattle'},
#  {'h.id': '986', 'c.name': 'Seattle'},
#  {'h.id': '987', 'c.name': 'Seattle'},
#  {'h.id': '988', 'c.name': 'Redmond'},
#  {'h.id': '989', 'c.name': 'Seattle'},
#  {'h.id': '990', 'c.name': 'Federal Way'},
#  {'h.id': '991', 'c.name': 'Covington'},
#  {'h.id': '992', 'c.name': 'SeaTac'},
#  {'h.id': '993', 'c.name': 'Federal Way'},
#  {'h.id': '994', 'c.name': 'Seattle'},
#  {'h.id': '995', 'c.name': 'Medina'},
#  {'h.id': '996', 'c.name': 'Shoreline'},
#  {'h.id': '997', 'c.name': 'Bellevue'},
#  {'h.id': '998', 'c.name': 'Seattle'},
#  {'h.id': '999', 'c.name': 'Renton'},
#  ...]
